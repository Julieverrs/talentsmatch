# %%
# Import necessary libraries
import pandas as pd

# Define the function to recommend applicants based on job data
def recommend_applicants(job_data):
    # Load the dataset (ensure the 'Datasets.csv' is in the same directory as this notebook or provide the correct path)
    df = pd.read_csv('Datasets.csv')

    # Clean the 'Experience' column: remove non-numeric characters (if any) and convert to integer
    df['Experience'] = df['Experience'].replace(r'[^\d]', '', regex=True).astype(int)

    # Filter out rows where Experience is NaN (if any)
    df = df.dropna(subset=['Experience'])

    # Extract required skills from the job_data input
    required_skills = job_data.get('required_skills', '')  # Comma-separated string
    skill_list = [skill.strip().lower() for skill in required_skills.split(',')]  # Split and clean skills

    # Debug: Print required skills
    print("Required Skills:", skill_list)

    # Check if the 'Skills' column exists in the dataset
    if 'Skills' in df.columns:
        df['Skills'] = df['Skills'].str.lower()  # Ensure all skills in the dataset are lowercase for comparison

        # Filter applicants based on required skills
        recommended = df[df['Skills'].apply(lambda skills: any(skill in skills for skill in skill_list))]

        # Optional: filter by Experience level if provided
        if 'experience_level' in job_data:
            experience_level = job_data['experience_level']
            recommended = recommended[recommended['Experience'] >= experience_level]

        # Ensure that Experience is displayed as an integer without the .0
        recommended['Experience'] = recommended['Experience'].astype(int)

        # Debug: Print filtered applicants
        print("Filtered Applicants:")
        print(recommended)

        # Return the filtered applicants in a dictionary format
        return recommended[['Name', 'Skills', 'Experience', 'Job_Title']].to_dict(orient='records')
    else:
        # Raise an error if the 'Skills' column is missing in the dataset
        raise KeyError("'Skills' column is missing from the dataset.")

# Example job data (to simulate user input from the Django form)
job_data = {
    'required_skills': 'Python, SQL, Docker',  # Comma-separated string of required skills
    'experience_level': 3  # Experience level filter (optional)
}

# Get the recommended applicants based on the job data
recommended_applicants = recommend_applicants(job_data)

# Display the recommended applicants in the notebook
recommended_applicants
# Out:
# Required Skills: ['python', 'sql', 'docker']
# Filtered Applicants:
#                    Name          Job_Title  \
# 1            Liam Smith  Software Engineer
# 15        Harper Harris  Software Engineer
# 19         Emma Johnson  Financial Analyst
# 29         Olivia Brown  Software Engineer
# 40         Elijah Moore  Software Engineer
# 46       Amelia Jackson  Financial Analyst
# 49           Liam Smith     Data Scientist
# 57      Isabella Martin     Data Scientist
# 71            Mason Lee  Software Engineer
# 72         Olivia Brown      Web Developer
# 91         Elijah Moore     Data Scientist
# 92           Liam Smith  Software Engineer
# 109          Ava Wilson  Software Engineer
# 115          Noah Davis     Data Scientist
# 131         Ethan White      Web Developer
# 153          Liam Smith     Data Scientist
# 155           Mason Lee     Data Scientist
# 188          Noah Davis  Software Engineer
# 191  Charlotte Thompson  Software Engineer
# 204          Noah Davis     Data Scientist
# 207          Mia Thomas      Web Developer
# 210      Amelia Jackson  Software Engineer
# 234       Harper Harris     Data Scientist
# 241          Noah Davis  Software Engineer
# 243          Noah Davis  Software Engineer
# 268          Ava Wilson  Software Engineer
# 278      Amelia Jackson     Data Scientist
# 288          Noah Davis     Data Scientist
# 330          Liam Smith  Software Engineer
# 354      Lucas Anderson  Software Engineer
# 363          Noah Davis     Data Scientist
# 365       Harper Harris  Software Engineer
# 373       Sophia Taylor     Data Scientist
# 380          Liam Smith     Data Scientist
# 384      Lucas Anderson     Data Scientist
# 387          Ava Wilson  Software Engineer
# 401          Liam Smith     Data Scientist
# 407          Liam Smith     Data Scientist
# 408       Sophia Taylor      Web Developer
# 417         Ethan White      Web Developer
# 420       Harper Harris      Web Developer
# 434          Noah Davis     Data Scientist
# 438          Ava Wilson  Financial Analyst
# 446       Harper Harris  Software Engineer
# 455          Noah Davis  Software Engineer
# 458          Noah Davis  Software Engineer
# 464     Isabella Martin  Software Engineer
# 473         Ethan White  Software Engineer
# 481       Sophia Taylor  Software Engineer
#
#                                      Skills  Experience
# 1              sql, cloud computing, docker           8
# 15             cloud computing, c++, python           3
# 19       financial modeling, budgeting, sql           9
# 29      kubernetes, cloud computing, python           4
# 40         javascript, sql, cloud computing          10
# 46        sql, financial modeling, power bi          10
# 49            machine learning, python, sql           4
# 57                deep learning, numpy, sql           3
# 71                  javascript, sql, python           5
# 72                           sql, git, html           4
# 91              python, machine learning, r          10
# 92             git, python, cloud computing           8
# 109                 git, python, javascript           3
# 115         machine learning, numpy, python           9
# 131                    vue.js, express, sql           8
# 153                  numpy, sql, statistics           4
# 155                machine learning, r, sql           7
# 188            python, cloud computing, sql           7
# 191               sql, c++, cloud computing           9
# 204              python, sql, deep learning           3
# 207                    vue.js, node.js, sql           5
# 210                kubernetes, java, docker           5
# 234            sql, numpy, machine learning           9
# 241                           git, sql, c++           6
# 243                     sql, docker, python           7
# 268                     python, c++, docker          10
# 278                          r, sql, pandas           8
# 288          deep learning, statistics, sql           3
# 330     docker, kubernetes, cloud computing          10
# 354                          sql, c++, java          10
# 363  tensorflow, python, data visualization           5
# 365                        python, c++, sql           6
# 373    tensorflow, machine learning, python           4
# 380           sql, python, machine learning           3
# 384                 statistics, python, sql           4
# 387                 docker, git, javascript           7
# 401                           r, sql, numpy          10
# 407                  statistics, numpy, sql           9
# 408                   javascript, sql, html           8
# 417                     node.js, sql, react           3
# 420                   sql, react, rest apis           6
# 434       machine learning, statistics, sql           8
# 438               power bi, quickbooks, sql           6
# 446              cloud computing, java, sql           6
# 455          agile, python, cloud computing           7
# 458             javascript, kubernetes, sql           4
# 464               docker, kubernetes, agile           5
# 473     kubernetes, cloud computing, docker           7
# 481            python, cloud computing, c++           9
# [{'Name': 'Liam Smith',
#   'Skills': 'sql, cloud computing, docker',
#   'Experience': 8,
#   'Job_Title': 'Software Engineer'},
#  {'Name': 'Harper Harris',
#   'Skills': 'cloud computing, c++, python',
#   'Experience': 3,
#   'Job_Title': 'Software Engineer'},
#  {'Name': 'Emma Johnson',
#   'Skills': 'financial modeling, budgeting, sql',
#   'Experience': 9,
#   'Job_Title': 'Financial Analyst'},
#  {'Name': 'Olivia Brown',
#   'Skills': 'kubernetes, cloud computing, python',
#   'Experience': 4,
#   'Job_Title': 'Software Engineer'},
#  {'Name': 'Elijah Moore',
#   'Skills': 'javascript, sql, cloud computing',
#   'Experience': 10,
#   'Job_Title': 'Software Engineer'},
#  {'Name': 'Amelia Jackson',
#   'Skills': 'sql, financial modeling, power bi',
#   'Experience': 10,
#   'Job_Title': 'Financial Analyst'},
#  {'Name': 'Liam Smith',
#   'Skills': 'machine learning, python, sql',
#   'Experience': 4,
#   'Job_Title': 'Data Scientist'},
#  {'Name': 'Isabella Martin',
#   'Skills': 'deep learning, numpy, sql',
#   'Experience': 3,
#   'Job_Title': 'Data Scientist'},
#  {'Name': 'Mason Lee',
#   'Skills': 'javascript, sql, python',
#   'Experience': 5,
#   'Job_Title': 'Software Engineer'},
#  {'Name': 'Olivia Brown',
#   'Skills': 'sql, git, html',
#   'Experience': 4,
#   'Job_Title': 'Web Developer'},
#  {'Name': 'Elijah Moore',
#   'Skills': 'python, machine learning, r',
#   'Experience': 10,
#   'Job_Title': 'Data Scientist'},
#  {'Name': 'Liam Smith',
#   'Skills': 'git, python, cloud computing',
#   'Experience': 8,
#   'Job_Title': 'Software Engineer'},
#  {'Name': 'Ava Wilson',
#   'Skills': 'git, python, javascript',
#   'Experience': 3,
#   'Job_Title': 'Software Engineer'},
#  {'Name': 'Noah Davis',
#   'Skills': 'machine learning, numpy, python',
#   'Experience': 9,
#   'Job_Title': 'Data Scientist'},
#  {'Name': 'Ethan White',
#   'Skills': 'vue.js, express, sql',
#   'Experience': 8,
#   'Job_Title': 'Web Developer'},
#  {'Name': 'Liam Smith',
#   'Skills': 'numpy, sql, statistics',
#   'Experience': 4,
#   'Job_Title': 'Data Scientist'},
#  {'Name': 'Mason Lee',
#   'Skills': 'machine learning, r, sql',
#   'Experience': 7,
#   'Job_Title': 'Data Scientist'},
#  {'Name': 'Noah Davis',
#   'Skills': 'python, cloud computing, sql',
#   'Experience': 7,
#   'Job_Title': 'Software Engineer'},
#  {'Name': 'Charlotte Thompson',
#   'Skills': 'sql, c++, cloud computing',
#   'Experience': 9,
#   'Job_Title': 'Software Engineer'},
#  {'Name': 'Noah Davis',
#   'Skills': 'python, sql, deep learning',
#   'Experience': 3,
#   'Job_Title': 'Data Scientist'},
#  {'Name': 'Mia Thomas',
#   'Skills': 'vue.js, node.js, sql',
#   'Experience': 5,
#   'Job_Title': 'Web Developer'},
#  {'Name': 'Amelia Jackson',
#   'Skills': 'kubernetes, java, docker',
#   'Experience': 5,
#   'Job_Title': 'Software Engineer'},
#  {'Name': 'Harper Harris',
#   'Skills': 'sql, numpy, machine learning',
#   'Experience': 9,
#   'Job_Title': 'Data Scientist'},
#  {'Name': 'Noah Davis',
#   'Skills': 'git, sql, c++',
#   'Experience': 6,
#   'Job_Title': 'Software Engineer'},
#  {'Name': 'Noah Davis',
#   'Skills': 'sql, docker, python',
#   'Experience': 7,
#   'Job_Title': 'Software Engineer'},
#  {'Name': 'Ava Wilson',
#   'Skills': 'python, c++, docker',
#   'Experience': 10,
#   'Job_Title': 'Software Engineer'},
#  {'Name': 'Amelia Jackson',
#   'Skills': 'r, sql, pandas',
#   'Experience': 8,
#   'Job_Title': 'Data Scientist'},
#  {'Name': 'Noah Davis',
#   'Skills': 'deep learning, statistics, sql',
#   'Experience': 3,
#   'Job_Title': 'Data Scientist'},
#  {'Name': 'Liam Smith',
#   'Skills': 'docker, kubernetes, cloud computing',
#   'Experience': 10,
#   'Job_Title': 'Software Engineer'},
#  {'Name': 'Lucas Anderson',
#   'Skills': 'sql, c++, java',
#   'Experience': 10,
#   'Job_Title': 'Software Engineer'},
#  {'Name': 'Noah Davis',
#   'Skills': 'tensorflow, python, data visualization',
#   'Experience': 5,
#   'Job_Title': 'Data Scientist'},
#  {'Name': 'Harper Harris',
#   'Skills': 'python, c++, sql',
#   'Experience': 6,
#   'Job_Title': 'Software Engineer'},
#  {'Name': 'Sophia Taylor',
#   'Skills': 'tensorflow, machine learning, python',
#   'Experience': 4,
#   'Job_Title': 'Data Scientist'},
#  {'Name': 'Liam Smith',
#   'Skills': 'sql, python, machine learning',
#   'Experience': 3,
#   'Job_Title': 'Data Scientist'},
#  {'Name': 'Lucas Anderson',
#   'Skills': 'statistics, python, sql',
#   'Experience': 4,
#   'Job_Title': 'Data Scientist'},
#  {'Name': 'Ava Wilson',
#   'Skills': 'docker, git, javascript',
#   'Experience': 7,
#   'Job_Title': 'Software Engineer'},
#  {'Name': 'Liam Smith',
#   'Skills': 'r, sql, numpy',
#   'Experience': 10,
#   'Job_Title': 'Data Scientist'},
#  {'Name': 'Liam Smith',
#   'Skills': 'statistics, numpy, sql',
#   'Experience': 9,
#   'Job_Title': 'Data Scientist'},
#  {'Name': 'Sophia Taylor',
#   'Skills': 'javascript, sql, html',
#   'Experience': 8,
#   'Job_Title': 'Web Developer'},
#  {'Name': 'Ethan White',
#   'Skills': 'node.js, sql, react',
#   'Experience': 3,
#   'Job_Title': 'Web Developer'},
#  {'Name': 'Harper Harris',
#   'Skills': 'sql, react, rest apis',
#   'Experience': 6,
#   'Job_Title': 'Web Developer'},
#  {'Name': 'Noah Davis',
#   'Skills': 'machine learning, statistics, sql',
#   'Experience': 8,
#   'Job_Title': 'Data Scientist'},
#  {'Name': 'Ava Wilson',
#   'Skills': 'power bi, quickbooks, sql',
#   'Experience': 6,
#   'Job_Title': 'Financial Analyst'},
#  {'Name': 'Harper Harris',
#   'Skills': 'cloud computing, java, sql',
#   'Experience': 6,
#   'Job_Title': 'Software Engineer'},
#  {'Name': 'Noah Davis',
#   'Skills': 'agile, python, cloud computing',
#   'Experience': 7,
#   'Job_Title': 'Software Engineer'},
#  {'Name': 'Noah Davis',
#   'Skills': 'javascript, kubernetes, sql',
#   'Experience': 4,
#   'Job_Title': 'Software Engineer'},
#  {'Name': 'Isabella Martin',
#   'Skills': 'docker, kubernetes, agile',
#   'Experience': 5,
#   'Job_Title': 'Software Engineer'},
#  {'Name': 'Ethan White',
#   'Skills': 'kubernetes, cloud computing, docker',
#   'Experience': 7,
#   'Job_Title': 'Software Engineer'},
#  {'Name': 'Sophia Taylor',
#   'Skills': 'python, cloud computing, c++',
#   'Experience': 9,
#   'Job_Title': 'Software Engineer'}]
